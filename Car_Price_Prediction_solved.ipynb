# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
#Importing Python Libraries
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
# Importing csv file into Colab enviornment from GitHub
url = 'https://raw.githubusercontent.com/SyedaHiraAmjad/Deep-Learning-Tech/main/CarPrice_Assignment.csv'
Car_data = pd.read_csv(url)
# Dataset is now stored in a Pandas Dataframe

# %%
Car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
Car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
#Check if there are  any empty cells
#If there are then row and column indexes will be returned where values are empty or missing
np.where(Car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
Car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
#Rectifying the name error in audi 100 ls
Car_data.iloc[3,2] = 'audi 100ls'

# %%
#Checking out data-types 
Car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
Car_data.drop(columns=['car_ID'], inplace = True)

# %%
# get columns so that we can use the column names for onehot encoding of catagorical featrues in next cell
Car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# OneHot Encoding of all catagorical columns
final_car = pd.get_dummies(Car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
#Checking the statistical data to see any abnormal values and outliers
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
#Initializing a seed value so that each time we can get the same random number sequence, it will help us  as a team
# Working on a common project to work on the same random data. Each new seed will generate a particular sequence of random number. You can choose any seed value here of your choice
# 0.72 means that we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data
#where the value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#Checking the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
# get our price labels and store in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
# drop price from oroginal training and test dataset , as price is not needed there
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
## we normalize data because data has big vlaues in decimal and it will worsen performance of our model, may overfit 
## or  we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
## firt take mean of training, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
#Checking mean
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
#Checking std
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
#Storing in numpy array
test = np.array(test_data.iloc[:]).astype('float32')
train = np.array(train_data.iloc[:]).astype('float32')
test_l= np.array(test_label.astype('float32'))
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Models section
# #####We will configure different models here according to relu, tanh , regularization, dropout etc..

# %%
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                1930
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section
# #####Here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout

# %%
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f5886b570e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58862c90e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58886a1b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58886a1440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58861ccf80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58862fc320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58886cf290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58898d5050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58886cfb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f588aaa1560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58d0444710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58862257a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 3ms/step - loss: 0.8798 - mae: 0.7653
# Epoch 2/100
# 106/106 [==============================] - 0s 3ms/step - loss: 1.0811 - mae: 0.7556
# Epoch 3/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7609 - mae: 0.7117
# Epoch 4/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.8255 - mae: 0.6493
# Epoch 5/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5238 - mae: 0.4916
# Epoch 6/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4581 - mae: 0.4276
# Epoch 7/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3422 - mae: 0.4037
# Epoch 8/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3272 - mae: 0.3777
# Epoch 9/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4218 - mae: 0.4229
# Epoch 10/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2495 - mae: 0.3632
# Epoch 11/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3290 - mae: 0.3931
# Epoch 12/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5065 - mae: 0.4227
# Epoch 13/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4989 - mae: 0.4551
# Epoch 14/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2527 - mae: 0.3675
# Epoch 15/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3553 - mae: 0.3606
# Epoch 16/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1414 - mae: 0.2825
# Epoch 17/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3169 - mae: 0.3574
# Epoch 18/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1671 - mae: 0.2981
# Epoch 19/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7308 - mae: 0.4966
# Epoch 20/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2867 - mae: 0.3698
# Epoch 21/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2937 - mae: 0.3657
# Epoch 22/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2104 - mae: 0.3416
# Epoch 23/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2360 - mae: 0.2912
# Epoch 24/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5970 - mae: 0.4255
# Epoch 25/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3746 - mae: 0.3659
# Epoch 26/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4024 - mae: 0.4211
# Epoch 27/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1988 - mae: 0.3129
# Epoch 28/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2304 - mae: 0.3139
# Epoch 29/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1698 - mae: 0.2699
# Epoch 30/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2254 - mae: 0.3349
# Epoch 31/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1840 - mae: 0.3096
# Epoch 32/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1499 - mae: 0.2736
# Epoch 33/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2059 - mae: 0.3205
# Epoch 34/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2713 - mae: 0.3642
# Epoch 35/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2552 - mae: 0.3053
# Epoch 36/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2031 - mae: 0.2744
# Epoch 37/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2496 - mae: 0.3518
# Epoch 38/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1216 - mae: 0.2321
# Epoch 39/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1737 - mae: 0.2862
# Epoch 40/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2056 - mae: 0.2884
# Epoch 41/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2167 - mae: 0.2580
# Epoch 42/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2265 - mae: 0.2981
# Epoch 43/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4121 - mae: 0.3652
# Epoch 44/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4628 - mae: 0.4151
# Epoch 45/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1404 - mae: 0.2454
# Epoch 46/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1521 - mae: 0.2481
# Epoch 47/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2237 - mae: 0.3045
# Epoch 48/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3721 - mae: 0.3217
# Epoch 49/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1321 - mae: 0.2462
# Epoch 50/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2064 - mae: 0.2781
# Epoch 51/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1992 - mae: 0.2924
# Epoch 52/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1452 - mae: 0.2490
# Epoch 53/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.0895 - mae: 0.1957
# Epoch 54/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1879 - mae: 0.2687
# Epoch 55/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3486 - mae: 0.2638
# Epoch 56/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3477 - mae: 0.3182
# Epoch 57/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2594 - mae: 0.2880
# Epoch 58/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2337 - mae: 0.2949
# Epoch 59/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1778 - mae: 0.2501
# Epoch 60/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2273 - mae: 0.2967
# Epoch 61/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.0848 - mae: 0.2173
# Epoch 62/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3188 - mae: 0.3412
# Epoch 63/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.0890 - mae: 0.2259
# Epoch 64/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1369 - mae: 0.2296
# Epoch 65/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3789 - mae: 0.3212
# Epoch 66/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4003 - mae: 0.3469
# Epoch 67/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1619 - mae: 0.2705
# Epoch 68/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1921 - mae: 0.2995
# Epoch 69/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3142 - mae: 0.3570
# Epoch 70/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2079 - mae: 0.2959
# Epoch 71/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1647 - mae: 0.2518
# Epoch 72/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2193 - mae: 0.3275
# Epoch 73/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3852 - mae: 0.3513
# Epoch 74/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1320 - mae: 0.2564
# Epoch 75/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3201 - mae: 0.3313
# Epoch 76/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2645 - mae: 0.2987
# Epoch 77/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1836 - mae: 0.2468
# Epoch 78/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2306 - mae: 0.2939
# Epoch 79/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1489 - mae: 0.2581
# Epoch 80/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1459 - mae: 0.2576
# Epoch 81/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.0758 - mae: 0.2067
# Epoch 82/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2224 - mae: 0.3054
# Epoch 83/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2244 - mae: 0.2629
# Epoch 84/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1640 - mae: 0.2807
# Epoch 85/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1477 - mae: 0.2786
# Epoch 86/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1842 - mae: 0.2464
# Epoch 87/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3013 - mae: 0.2558
# Epoch 88/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2141 - mae: 0.3107
# Epoch 89/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2456 - mae: 0.3097
# Epoch 90/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3201 - mae: 0.3364
# Epoch 91/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3603 - mae: 0.3050
# Epoch 92/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1476 - mae: 0.2663
# Epoch 93/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3250 - mae: 0.3369
# Epoch 94/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1966 - mae: 0.2905
# Epoch 95/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1193 - mae: 0.2232
# Epoch 96/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2188 - mae: 0.2904
# Epoch 97/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2802 - mae: 0.2865
# Epoch 98/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1869 - mae: 0.2982
# Epoch 99/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3182 - mae: 0.3247
# Epoch 100/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1893 - mae: 0.2895
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f588981e4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3396 - mae: 0.3597
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 3ms/step - loss: 1.1885 - mae: 0.8110
# Epoch 2/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5569 - mae: 0.5933
# Epoch 3/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7266 - mae: 0.5975
# Epoch 4/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4869 - mae: 0.4673
# Epoch 5/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3022 - mae: 0.3457
# Epoch 6/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4517 - mae: 0.4342
# Epoch 7/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7605 - mae: 0.5491
# Epoch 8/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3701 - mae: 0.4477
# Epoch 9/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3956 - mae: 0.4124
# Epoch 10/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5160 - mae: 0.5015
# Epoch 11/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4225 - mae: 0.3885
# Epoch 12/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3244 - mae: 0.3958
# Epoch 13/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2277 - mae: 0.3788
# Epoch 14/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4859 - mae: 0.4596
# Epoch 15/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4245 - mae: 0.4379
# Epoch 16/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4146 - mae: 0.3958
# Epoch 17/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4332 - mae: 0.4075
# Epoch 18/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4815 - mae: 0.3906
# Epoch 19/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3738 - mae: 0.4343
# Epoch 20/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4382 - mae: 0.4774
# Epoch 21/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4605 - mae: 0.4069
# Epoch 22/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1594 - mae: 0.2943
# Epoch 23/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3406 - mae: 0.3563
# Epoch 24/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2274 - mae: 0.3652
# Epoch 25/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2004 - mae: 0.3035
# Epoch 26/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3063 - mae: 0.3775
# Epoch 27/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3111 - mae: 0.3378
# Epoch 28/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2585 - mae: 0.3572
# Epoch 29/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4930 - mae: 0.3968
# Epoch 30/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2572 - mae: 0.3670
# Epoch 31/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1681 - mae: 0.2801
# Epoch 32/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4083 - mae: 0.3605
# Epoch 33/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2192 - mae: 0.3016
# Epoch 34/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2428 - mae: 0.3265
# Epoch 35/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3440 - mae: 0.3605
# Epoch 36/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4875 - mae: 0.4109
# Epoch 37/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1865 - mae: 0.3192
# Epoch 38/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3491 - mae: 0.4371
# Epoch 39/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2624 - mae: 0.3418
# Epoch 40/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4380 - mae: 0.3609
# Epoch 41/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2238 - mae: 0.3244
# Epoch 42/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2434 - mae: 0.3113
# Epoch 43/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1636 - mae: 0.3021
# Epoch 44/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2223 - mae: 0.3320
# Epoch 45/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2399 - mae: 0.2851
# Epoch 46/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1589 - mae: 0.2720
# Epoch 47/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2269 - mae: 0.3378
# Epoch 48/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2367 - mae: 0.3649
# Epoch 49/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3050 - mae: 0.3807
# Epoch 50/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1505 - mae: 0.2634
# Epoch 51/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2986 - mae: 0.3303
# Epoch 52/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1932 - mae: 0.2999
# Epoch 53/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2450 - mae: 0.3050
# Epoch 54/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1769 - mae: 0.2855
# Epoch 55/100
# 106/106 [==============================] - 0s 4ms/step - loss: 0.3440 - mae: 0.3557
# Epoch 56/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1743 - mae: 0.2913
# Epoch 57/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2187 - mae: 0.2876
# Epoch 58/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1877 - mae: 0.2455
# Epoch 59/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1899 - mae: 0.2962
# Epoch 60/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2300 - mae: 0.2843
# Epoch 61/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1502 - mae: 0.2906
# Epoch 62/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2151 - mae: 0.3306
# Epoch 63/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1297 - mae: 0.2513
# Epoch 64/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1745 - mae: 0.2526
# Epoch 65/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2244 - mae: 0.3086
# Epoch 66/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2053 - mae: 0.3045
# Epoch 67/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1589 - mae: 0.2542
# Epoch 68/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1423 - mae: 0.2440
# Epoch 69/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3904 - mae: 0.3796
# Epoch 70/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3095 - mae: 0.3298
# Epoch 71/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1637 - mae: 0.2605
# Epoch 72/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2377 - mae: 0.3244
# Epoch 73/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4323 - mae: 0.3178
# Epoch 74/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1028 - mae: 0.2434
# Epoch 75/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2780 - mae: 0.3388
# Epoch 76/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2581 - mae: 0.2876
# Epoch 77/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5723 - mae: 0.4181
# Epoch 78/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1588 - mae: 0.2736
# Epoch 79/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2140 - mae: 0.3005
# Epoch 80/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2311 - mae: 0.3411
# Epoch 81/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1487 - mae: 0.2390
# Epoch 82/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1159 - mae: 0.2464
# Epoch 83/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1613 - mae: 0.2407
# Epoch 84/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3608 - mae: 0.3151
# Epoch 85/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2729 - mae: 0.2883
# Epoch 86/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1335 - mae: 0.2373
# Epoch 87/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2014 - mae: 0.2793
# Epoch 88/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3290 - mae: 0.3080
# Epoch 89/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1195 - mae: 0.2162
# Epoch 90/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4816 - mae: 0.3605
# Epoch 91/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2728 - mae: 0.3141
# Epoch 92/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2195 - mae: 0.3147
# Epoch 93/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2606 - mae: 0.2888
# Epoch 94/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2088 - mae: 0.3089
# Epoch 95/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1707 - mae: 0.2668
# Epoch 96/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1531 - mae: 0.2780
# Epoch 97/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2000 - mae: 0.2915
# Epoch 98/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1688 - mae: 0.2760
# Epoch 99/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2061 - mae: 0.2330
# Epoch 100/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1867 - mae: 0.2528
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f588a9e7f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6518 - mae: 0.4597
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 3ms/step - loss: 1.1120 - mae: 0.7727
# Epoch 2/100
# 106/106 [==============================] - 0s 3ms/step - loss: 1.2470 - mae: 0.7537
# Epoch 3/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6479 - mae: 0.5532
# Epoch 4/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4690 - mae: 0.4624
# Epoch 5/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4214 - mae: 0.4664
# Epoch 6/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.9511 - mae: 0.5795
# Epoch 7/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4189 - mae: 0.4351
# Epoch 8/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4293 - mae: 0.4282
# Epoch 9/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3038 - mae: 0.4009
# Epoch 10/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7958 - mae: 0.5561
# Epoch 11/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2171 - mae: 0.3699
# Epoch 12/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5726 - mae: 0.4766
# Epoch 13/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3679 - mae: 0.4161
# Epoch 14/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2478 - mae: 0.3451
# Epoch 15/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7257 - mae: 0.5471
# Epoch 16/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2906 - mae: 0.4007
# Epoch 17/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3118 - mae: 0.4079
# Epoch 18/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5213 - mae: 0.4849
# Epoch 19/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4294 - mae: 0.4022
# Epoch 20/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3877 - mae: 0.3790
# Epoch 21/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2820 - mae: 0.3767
# Epoch 22/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7147 - mae: 0.5455
# Epoch 23/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4958 - mae: 0.4608
# Epoch 24/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3510 - mae: 0.3605
# Epoch 25/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5149 - mae: 0.3989
# Epoch 26/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5046 - mae: 0.4260
# Epoch 27/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4194 - mae: 0.4216
# Epoch 28/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3256 - mae: 0.3649
# Epoch 29/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3829 - mae: 0.3871
# Epoch 30/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7481 - mae: 0.4883
# Epoch 31/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3156 - mae: 0.4090
# Epoch 32/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3849 - mae: 0.3418
# Epoch 33/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3156 - mae: 0.3553
# Epoch 34/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5667 - mae: 0.4490
# Epoch 35/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4150 - mae: 0.3924
# Epoch 36/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3446 - mae: 0.3751
# Epoch 37/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2398 - mae: 0.3341
# Epoch 38/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3142 - mae: 0.3880
# Epoch 39/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3952 - mae: 0.3567
# Epoch 40/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3045 - mae: 0.3779
# Epoch 41/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6082 - mae: 0.4801
# Epoch 42/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4417 - mae: 0.3999
# Epoch 43/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3258 - mae: 0.3952
# Epoch 44/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3752 - mae: 0.4276
# Epoch 45/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3107 - mae: 0.4007
# Epoch 46/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1446 - mae: 0.2681
# Epoch 47/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3111 - mae: 0.3005
# Epoch 48/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2758 - mae: 0.3592
# Epoch 49/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1466 - mae: 0.2806
# Epoch 50/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4443 - mae: 0.3946
# Epoch 51/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3472 - mae: 0.3711
# Epoch 52/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2570 - mae: 0.3488
# Epoch 53/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2701 - mae: 0.3455
# Epoch 54/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2101 - mae: 0.3369
# Epoch 55/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2673 - mae: 0.3388
# Epoch 56/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1642 - mae: 0.2373
# Epoch 57/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2196 - mae: 0.3294
# Epoch 58/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1830 - mae: 0.3137
# Epoch 59/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4770 - mae: 0.4400
# Epoch 60/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4489 - mae: 0.3914
# Epoch 61/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4086 - mae: 0.3581
# Epoch 62/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3320 - mae: 0.3451
# Epoch 63/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2400 - mae: 0.3055
# Epoch 64/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4096 - mae: 0.3855
# Epoch 65/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4263 - mae: 0.3802
# Epoch 66/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5647 - mae: 0.4487
# Epoch 67/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3004 - mae: 0.3568
# Epoch 68/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4561 - mae: 0.4265
# Epoch 69/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3749 - mae: 0.3786
# Epoch 70/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2829 - mae: 0.3617
# Epoch 71/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1924 - mae: 0.2934
# Epoch 72/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1765 - mae: 0.2897
# Epoch 73/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2398 - mae: 0.3169
# Epoch 74/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3117 - mae: 0.3229
# Epoch 75/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2420 - mae: 0.3126
# Epoch 76/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1254 - mae: 0.2514
# Epoch 77/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2639 - mae: 0.3061
# Epoch 78/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2746 - mae: 0.3706
# Epoch 79/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5767 - mae: 0.4033
# Epoch 80/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1802 - mae: 0.2788
# Epoch 81/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4411 - mae: 0.3912
# Epoch 82/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1985 - mae: 0.3062
# Epoch 83/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2551 - mae: 0.3212
# Epoch 84/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2675 - mae: 0.2859
# Epoch 85/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.0965 - mae: 0.2263
# Epoch 86/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1573 - mae: 0.2517
# Epoch 87/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2576 - mae: 0.2694
# Epoch 88/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3681 - mae: 0.3662
# Epoch 89/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5213 - mae: 0.4368
# Epoch 90/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1758 - mae: 0.2855
# Epoch 91/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1600 - mae: 0.2440
# Epoch 92/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6492 - mae: 0.3855
# Epoch 93/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3103 - mae: 0.3729
# Epoch 94/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1996 - mae: 0.2824
# Epoch 95/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2607 - mae: 0.3276
# Epoch 96/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2818 - mae: 0.3486
# Epoch 97/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4911 - mae: 0.3591
# Epoch 98/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1460 - mae: 0.2509
# Epoch 99/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3173 - mae: 0.3273
# Epoch 100/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1916 - mae: 0.2630
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f5888641290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2508 - mae: 0.3465
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 3ms/step - loss: 1.1420 - mae: 0.6863
# Epoch 2/100
# 106/106 [==============================] - 0s 3ms/step - loss: 1.0884 - mae: 0.7110
# Epoch 3/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6823 - mae: 0.5271
# Epoch 4/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.8810 - mae: 0.6495
# Epoch 5/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.9310 - mae: 0.6096
# Epoch 6/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.9820 - mae: 0.6414
# Epoch 7/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7211 - mae: 0.6106
# Epoch 8/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5049 - mae: 0.4739
# Epoch 9/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4267 - mae: 0.4652
# Epoch 10/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7594 - mae: 0.5934
# Epoch 11/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5404 - mae: 0.4777
# Epoch 12/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5805 - mae: 0.5493
# Epoch 13/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3462 - mae: 0.4021
# Epoch 14/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.7185 - mae: 0.5145
# Epoch 15/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5385 - mae: 0.4605
# Epoch 16/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3560 - mae: 0.4143
# Epoch 17/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3165 - mae: 0.4248
# Epoch 18/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4015 - mae: 0.4271
# Epoch 19/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6838 - mae: 0.5453
# Epoch 20/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6760 - mae: 0.5183
# Epoch 21/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3840 - mae: 0.4155
# Epoch 22/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4160 - mae: 0.3887
# Epoch 23/100
# 106/106 [==============================] - 0s 3ms/step - loss: 1.0376 - mae: 0.6342
# Epoch 24/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3622 - mae: 0.4040
# Epoch 25/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2513 - mae: 0.3350
# Epoch 26/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4500 - mae: 0.4134
# Epoch 27/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3678 - mae: 0.4014
# Epoch 28/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2804 - mae: 0.3510
# Epoch 29/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2717 - mae: 0.3467
# Epoch 30/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3779 - mae: 0.3968
# Epoch 31/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5902 - mae: 0.4813
# Epoch 32/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5565 - mae: 0.4525
# Epoch 33/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2091 - mae: 0.3548
# Epoch 34/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5205 - mae: 0.3969
# Epoch 35/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3435 - mae: 0.3942
# Epoch 36/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2420 - mae: 0.2796
# Epoch 37/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4551 - mae: 0.4295
# Epoch 38/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5297 - mae: 0.4122
# Epoch 39/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3219 - mae: 0.3872
# Epoch 40/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2163 - mae: 0.2960
# Epoch 41/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1691 - mae: 0.2791
# Epoch 42/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2999 - mae: 0.3601
# Epoch 43/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4188 - mae: 0.4373
# Epoch 44/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1632 - mae: 0.2904
# Epoch 45/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3476 - mae: 0.3361
# Epoch 46/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3762 - mae: 0.3715
# Epoch 47/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1702 - mae: 0.3017
# Epoch 48/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3029 - mae: 0.3387
# Epoch 49/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2348 - mae: 0.3399
# Epoch 50/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2434 - mae: 0.3087
# Epoch 51/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2380 - mae: 0.3334
# Epoch 52/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6316 - mae: 0.4740
# Epoch 53/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4923 - mae: 0.4189
# Epoch 54/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2486 - mae: 0.3036
# Epoch 55/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3401 - mae: 0.3536
# Epoch 56/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2938 - mae: 0.3261
# Epoch 57/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2646 - mae: 0.3317
# Epoch 58/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4765 - mae: 0.4240
# Epoch 59/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6639 - mae: 0.4789
# Epoch 60/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3707 - mae: 0.3563
# Epoch 61/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3043 - mae: 0.3460
# Epoch 62/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3313 - mae: 0.3289
# Epoch 63/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2796 - mae: 0.3171
# Epoch 64/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2787 - mae: 0.3238
# Epoch 65/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.4079 - mae: 0.4183
# Epoch 66/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2199 - mae: 0.3478
# Epoch 67/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1826 - mae: 0.2647
# Epoch 68/100
# 106/106 [==============================] - 0s 4ms/step - loss: 0.2466 - mae: 0.3405
# Epoch 69/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3251 - mae: 0.3630
# Epoch 70/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3506 - mae: 0.3900
# Epoch 71/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2374 - mae: 0.3680
# Epoch 72/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1787 - mae: 0.2777
# Epoch 73/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3907 - mae: 0.3712
# Epoch 74/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1533 - mae: 0.2780
# Epoch 75/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1683 - mae: 0.2814
# Epoch 76/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6656 - mae: 0.4385
# Epoch 77/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1961 - mae: 0.2950
# Epoch 78/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2032 - mae: 0.3005
# Epoch 79/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2454 - mae: 0.2956
# Epoch 80/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6386 - mae: 0.4640
# Epoch 81/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2316 - mae: 0.3265
# Epoch 82/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3650 - mae: 0.3217
# Epoch 83/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2978 - mae: 0.3228
# Epoch 84/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1959 - mae: 0.2848
# Epoch 85/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1045 - mae: 0.2323
# Epoch 86/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1856 - mae: 0.3114
# Epoch 87/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1801 - mae: 0.2838
# Epoch 88/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2576 - mae: 0.3384
# Epoch 89/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1711 - mae: 0.2943
# Epoch 90/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2814 - mae: 0.3482
# Epoch 91/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2319 - mae: 0.3163
# Epoch 92/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1359 - mae: 0.2530
# Epoch 93/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2439 - mae: 0.3077
# Epoch 94/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2116 - mae: 0.2922
# Epoch 95/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1998 - mae: 0.2929
# Epoch 96/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3916 - mae: 0.3943
# Epoch 97/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2457 - mae: 0.3057
# Epoch 98/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.8515 - mae: 0.4859
# Epoch 99/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.5441 - mae: 0.4199
# Epoch 100/100
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3055 - mae: 0.3871
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f588983cdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1384 - mae: 0.2634

# %% [markdown]
# # Scores
# ##### Here we will see MAE Mean Absolute Error scores of all model which we saved in the list during each training in above section

# %%
all_scores_relu
# Out:
# [0.3317689299583435,
#  0.32334429025650024,
#  0.3742559254169464,
#  0.3272038698196411]

# %%
all_scores_tanh
# Out:
# [0.33123257756233215,
#  0.39266008138656616,
#  0.47880983352661133,
#  0.2731391191482544]

# %%
all_scores_regular
# Out:
# [0.36970624327659607,
#  0.25527021288871765,
#  0.338309645652771,
#  0.3413254916667938]

# %%
all_scores_drop
# Out:
# [0.3597089350223541,
#  0.45972388982772827,
#  0.34647661447525024,
#  0.2634308338165283]

# %% [markdown]
# # Training on the training data
# #####Here we will call each model separately from Models section and train on the training data and evaluate on the test data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58d0146560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1031 - mae: 0.2399

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58d01dd710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0857 - mae: 0.2294

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f58886a1ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1431 - mae: 0.2665

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f5886288560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1008 - mae: 0.2578

# %% [markdown]
# # Prediction Section
# #####Here we will predict our prices of our test dataset with each model which we have trained in training section
# #####Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21029.117]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[22702.328]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[25815.182]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20423.402]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f58861519e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5886151710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5885914e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5887471cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
